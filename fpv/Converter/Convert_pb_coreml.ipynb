# %%
import tfcoreml as tf_converter

# %%
import tensorflow as tf

# %% [markdown]
# ## Output the graph
#
# In this step we just want to know the exact name of input and output nodes in the tensorflow graph

# %%
def load_graph(frozen_graph_filename):
    # We load the protobuf file from the disk and parse it to retrieve the 
    # unserialized graph_def
    with tf.gfile.GFile(frozen_graph_filename, "rb") as f:
        graph_def = tf.GraphDef()
        graph_def.ParseFromString(f.read())

    # Then, we import the graph_def into a new Graph and return it 
    with tf.Graph().as_default() as graph:
        tf.import_graph_def(graph_def, name="")
    return graph

graph = load_graph('yolo.pb')
for op in graph.get_operations(): 
    print (op.name)
# Out:
# input
# Pad/paddings
# Pad
# 0-convolutional/filter
# 0-convolutional
# sub/y
# sub
# truediv/y
# truediv
# mul/y
# mul
# BiasAdd/bias
# BiasAdd
# mul_1/x
# mul_1
# 1-leaky
# 2-maxpool
# Pad_1/paddings
# Pad_1
# 3-convolutional/filter
# 3-convolutional
# sub_1/y
# sub_1
# truediv_1/y
# truediv_1
# mul_2/y
# mul_2
# BiasAdd_1/bias
# BiasAdd_1
# mul_3/x
# mul_3
# 4-leaky
# 5-maxpool
# Pad_2/paddings
# Pad_2
# 6-convolutional/filter
# 6-convolutional
# sub_2/y
# sub_2
# truediv_2/y
# truediv_2
# mul_4/y
# mul_4
# BiasAdd_2/bias
# BiasAdd_2
# mul_5/x
# mul_5
# 7-leaky
# Pad_3/paddings
# Pad_3
# 8-convolutional/filter
# 8-convolutional
# sub_3/y
# sub_3
# truediv_3/y
# truediv_3
# mul_6/y
# mul_6
# BiasAdd_3/bias
# BiasAdd_3
# mul_7/x
# mul_7
# 9-leaky
# Pad_4/paddings
# Pad_4
# 10-convolutional/filter
# 10-convolutional
# sub_4/y
# sub_4
# truediv_4/y
# truediv_4
# mul_8/y
# mul_8
# BiasAdd_4/bias
# BiasAdd_4
# mul_9/x
# mul_9
# 11-leaky
# 12-maxpool
# Pad_5/paddings
# Pad_5
# 13-convolutional/filter
# 13-convolutional
# sub_5/y
# sub_5
# truediv_5/y
# truediv_5
# mul_10/y
# mul_10
# BiasAdd_5/bias
# BiasAdd_5
# mul_11/x
# mul_11
# 14-leaky
# Pad_6/paddings
# Pad_6
# 15-convolutional/filter
# 15-convolutional
# sub_6/y
# sub_6
# truediv_6/y
# truediv_6
# mul_12/y
# mul_12
# BiasAdd_6/bias
# BiasAdd_6
# mul_13/x
# mul_13
# 16-leaky
# Pad_7/paddings
# Pad_7
# 17-convolutional/filter
# 17-convolutional
# sub_7/y
# sub_7
# truediv_7/y
# truediv_7
# mul_14/y
# mul_14
# BiasAdd_7/bias
# BiasAdd_7
# mul_15/x
# mul_15
# 18-leaky
# 19-maxpool
# Pad_8/paddings
# Pad_8
# 20-convolutional/filter
# 20-convolutional
# sub_8/y
# sub_8
# truediv_8/y
# truediv_8
# mul_16/y
# mul_16
# BiasAdd_8/bias
# BiasAdd_8
# mul_17/x
# mul_17
# 21-leaky
# Pad_9/paddings
# Pad_9
# 22-convolutional/filter
# 22-convolutional
# sub_9/y
# sub_9
# truediv_9/y
# truediv_9
# mul_18/y
# mul_18
# BiasAdd_9/bias
# BiasAdd_9
# mul_19/x
# mul_19
# 23-leaky
# Pad_10/paddings
# Pad_10
# 24-convolutional/filter
# 24-convolutional
# sub_10/y
# sub_10
# truediv_10/y
# truediv_10
# mul_20/y
# mul_20
# BiasAdd_10/bias
# BiasAdd_10
# mul_21/x
# mul_21
# 25-leaky
# Pad_11/paddings
# Pad_11
# 26-convolutional/filter
# 26-convolutional
# sub_11/y
# sub_11
# truediv_11/y
# truediv_11
# mul_22/y
# mul_22
# BiasAdd_11/bias
# BiasAdd_11
# mul_23/x
# mul_23
# 27-leaky
# Pad_12/paddings
# Pad_12
# 28-convolutional/filter
# 28-convolutional
# sub_12/y
# sub_12
# truediv_12/y
# truediv_12
# mul_24/y
# mul_24
# BiasAdd_12/bias
# BiasAdd_12
# mul_25/x
# mul_25
# 29-leaky
# 30-maxpool
# Pad_13/paddings
# Pad_13
# 31-convolutional/filter
# 31-convolutional
# sub_13/y
# sub_13
# truediv_13/y
# truediv_13
# mul_26/y
# mul_26
# BiasAdd_13/bias
# BiasAdd_13
# mul_27/x
# mul_27
# 32-leaky
# Pad_14/paddings
# Pad_14
# 33-convolutional/filter
# 33-convolutional
# sub_14/y
# sub_14
# truediv_14/y
# truediv_14
# mul_28/y
# mul_28
# BiasAdd_14/bias
# BiasAdd_14
# mul_29/x
# mul_29
# 34-leaky
# Pad_15/paddings
# Pad_15
# 35-convolutional/filter
# 35-convolutional
# sub_15/y
# sub_15
# truediv_15/y
# truediv_15
# mul_30/y
# mul_30
# BiasAdd_15/bias
# BiasAdd_15
# mul_31/x
# mul_31
# 36-leaky
# Pad_16/paddings
# Pad_16
# 37-convolutional/filter
# 37-convolutional
# sub_16/y
# sub_16
# truediv_16/y
# truediv_16
# mul_32/y
# mul_32
# BiasAdd_16/bias
# BiasAdd_16
# mul_33/x
# mul_33
# 38-leaky
# Pad_17/paddings
# Pad_17
# 39-convolutional/filter
# 39-convolutional
# sub_17/y
# sub_17
# truediv_17/y
# truediv_17
# mul_34/y
# mul_34
# BiasAdd_17/bias
# BiasAdd_17
# mul_35/x
# mul_35
# 40-leaky
# Pad_18/paddings
# Pad_18
# 41-convolutional/filter
# 41-convolutional
# sub_18/y
# sub_18
# truediv_18/y
# truediv_18
# mul_36/y
# mul_36
# BiasAdd_18/bias
# BiasAdd_18
# mul_37/x
# mul_37
# 42-leaky
# Pad_19/paddings
# Pad_19
# 43-convolutional/filter
# 43-convolutional
# sub_19/y
# sub_19
# truediv_19/y
# truediv_19
# mul_38/y
# mul_38
# BiasAdd_19/bias
# BiasAdd_19
# mul_39/x
# mul_39
# 44-leaky
# concat/concat_dim
# concat
# Pad_20/paddings
# Pad_20
# 46-convolutional/filter
# 46-convolutional
# sub_20/y
# sub_20
# truediv_20/y
# truediv_20
# mul_40/y
# mul_40
# BiasAdd_20/bias
# BiasAdd_20
# mul_41/x
# mul_41
# 47-leaky
# ExtractImagePatches
# concat_1/axis
# concat_1
# Pad_21/paddings
# Pad_21
# 50-convolutional/filter
# 50-convolutional
# sub_21/y
# sub_21
# truediv_21/y
# truediv_21
# mul_42/y
# mul_42
# BiasAdd_21/bias
# BiasAdd_21
# mul_43/x
# mul_43
# 51-leaky
# Pad_22/paddings
# Pad_22
# 52-convolutional/filter
# 52-convolutional
# BiasAdd_22/bias
# BiasAdd_22
# output
# init

# %% [markdown]
# ## Convert to mlmodel format
#
# In the previose step, we know the output and input node names. And we can also get the input shape size from the cfg file. We specify these in the convert procedure and save the mlmodel file as `yolo.mlmodel` .

# %%
coreml_model = tf_converter.convert(tf_model_path = 'yolo.pb',
                                     mlmodel_path = 'yolo.mlmodel',
                             output_feature_names = ['output:0'],  # the output node name we get from the previouse step
                                 image_input_names= ['input:0'],   # CoreML allows image as the input, the only thing we need to do is to set which node is the image input node 
                            input_name_shape_dict = {'input:0' : [1, 608, 608, 3]},  # the input node name we get from the previous step, and check the cfg file to know the exact input shape size
                                   is_bgr = True,   # the channel order is by BGR instead of RGB
                                   image_scale = 1 / 255.0)	 # the weights is already normalized in the range from 0 to 1
# Out:
# (80, ' classes')
# Shapes not found for 189 tensors. Executing graph to determine shapes.
# Automatic shape interpretation succeeded for input blob input:0
# 161/349: Converting op name: input ( type:  Placeholder )
# Skipping name of placeholder
# 162/349: Converting op name: Pad ( type:  Pad )
# 163/349: Converting op name: 0-convolutional ( type:  Conv2D )
# 164/349: Converting op name: sub ( type:  Sub )
# 165/349: Converting op name: truediv ( type:  RealDiv )
# 166/349: Converting op name: mul ( type:  Mul )
# 167/349: Converting op name: BiasAdd ( type:  BiasAdd )
# 168/349: Converting op name: mul_1 ( type:  Mul )
# 169/349: Converting op name: 1-leaky ( type:  Maximum )
# 170/349: Converting op name: 2-maxpool ( type:  MaxPool )
# 171/349: Converting op name: Pad_1 ( type:  Pad )
# 172/349: Converting op name: 3-convolutional ( type:  Conv2D )
# 173/349: Converting op name: sub_1 ( type:  Sub )
# 174/349: Converting op name: truediv_1 ( type:  RealDiv )
# 175/349: Converting op name: mul_2 ( type:  Mul )
# 176/349: Converting op name: BiasAdd_1 ( type:  BiasAdd )
# 177/349: Converting op name: mul_3 ( type:  Mul )
# 178/349: Converting op name: 4-leaky ( type:  Maximum )
# 179/349: Converting op name: 5-maxpool ( type:  MaxPool )
# 180/349: Converting op name: Pad_2 ( type:  Pad )
# 181/349: Converting op name: 6-convolutional ( type:  Conv2D )
# 182/349: Converting op name: sub_2 ( type:  Sub )
# 183/349: Converting op name: truediv_2 ( type:  RealDiv )
# 184/349: Converting op name: mul_4 ( type:  Mul )
# 185/349: Converting op name: BiasAdd_2 ( type:  BiasAdd )
# 186/349: Converting op name: mul_5 ( type:  Mul )
# 187/349: Converting op name: 7-leaky ( type:  Maximum )
# 188/349: Converting op name: Pad_3 ( type:  Pad )
# 189/349: Converting op name: 8-convolutional ( type:  Conv2D )
# 190/349: Converting op name: sub_3 ( type:  Sub )
# 191/349: Converting op name: truediv_3 ( type:  RealDiv )
# 192/349: Converting op name: mul_6 ( type:  Mul )
# 193/349: Converting op name: BiasAdd_3 ( type:  BiasAdd )
# 194/349: Converting op name: mul_7 ( type:  Mul )
# 195/349: Converting op name: 9-leaky ( type:  Maximum )
# 196/349: Converting op name: Pad_4 ( type:  Pad )
# 197/349: Converting op name: 10-convolutional ( type:  Conv2D )
# 198/349: Converting op name: sub_4 ( type:  Sub )
# 199/349: Converting op name: truediv_4 ( type:  RealDiv )
# 200/349: Converting op name: mul_8 ( type:  Mul )
# 201/349: Converting op name: BiasAdd_4 ( type:  BiasAdd )
# 202/349: Converting op name: mul_9 ( type:  Mul )
# 203/349: Converting op name: 11-leaky ( type:  Maximum )
# 204/349: Converting op name: 12-maxpool ( type:  MaxPool )
# 205/349: Converting op name: Pad_5 ( type:  Pad )
# 206/349: Converting op name: 13-convolutional ( type:  Conv2D )
# 207/349: Converting op name: sub_5 ( type:  Sub )
# 208/349: Converting op name: truediv_5 ( type:  RealDiv )
# 209/349: Converting op name: mul_10 ( type:  Mul )
# 210/349: Converting op name: BiasAdd_5 ( type:  BiasAdd )
# 211/349: Converting op name: mul_11 ( type:  Mul )
# 212/349: Converting op name: 14-leaky ( type:  Maximum )
# 213/349: Converting op name: Pad_6 ( type:  Pad )
# 214/349: Converting op name: 15-convolutional ( type:  Conv2D )
# 215/349: Converting op name: sub_6 ( type:  Sub )
# 216/349: Converting op name: truediv_6 ( type:  RealDiv )
# 217/349: Converting op name: mul_12 ( type:  Mul )
# 218/349: Converting op name: BiasAdd_6 ( type:  BiasAdd )
# 219/349: Converting op name: mul_13 ( type:  Mul )
# 220/349: Converting op name: 16-leaky ( type:  Maximum )
# 221/349: Converting op name: Pad_7 ( type:  Pad )
# 222/349: Converting op name: 17-convolutional ( type:  Conv2D )
# 223/349: Converting op name: sub_7 ( type:  Sub )
# 224/349: Converting op name: truediv_7 ( type:  RealDiv )
# 225/349: Converting op name: mul_14 ( type:  Mul )
# 226/349: Converting op name: BiasAdd_7 ( type:  BiasAdd )
# 227/349: Converting op name: mul_15 ( type:  Mul )
# 228/349: Converting op name: 18-leaky ( type:  Maximum )
# 229/349: Converting op name: 19-maxpool ( type:  MaxPool )
# 230/349: Converting op name: Pad_8 ( type:  Pad )
# 231/349: Converting op name: 20-convolutional ( type:  Conv2D )
# 232/349: Converting op name: sub_8 ( type:  Sub )
# 233/349: Converting op name: truediv_8 ( type:  RealDiv )
# 234/349: Converting op name: mul_16 ( type:  Mul )
# 235/349: Converting op name: BiasAdd_8 ( type:  BiasAdd )
# 236/349: Converting op name: mul_17 ( type:  Mul )
# 237/349: Converting op name: 21-leaky ( type:  Maximum )
# 238/349: Converting op name: Pad_9 ( type:  Pad )
# 239/349: Converting op name: 22-convolutional ( type:  Conv2D )
# 240/349: Converting op name: sub_9 ( type:  Sub )
# 241/349: Converting op name: truediv_9 ( type:  RealDiv )
# 242/349: Converting op name: mul_18 ( type:  Mul )
# 243/349: Converting op name: BiasAdd_9 ( type:  BiasAdd )
# 244/349: Converting op name: mul_19 ( type:  Mul )
# 245/349: Converting op name: 23-leaky ( type:  Maximum )
# 246/349: Converting op name: Pad_10 ( type:  Pad )
# 247/349: Converting op name: 24-convolutional ( type:  Conv2D )
# 248/349: Converting op name: sub_10 ( type:  Sub )
# 249/349: Converting op name: truediv_10 ( type:  RealDiv )
# 250/349: Converting op name: mul_20 ( type:  Mul )
# 251/349: Converting op name: BiasAdd_10 ( type:  BiasAdd )
# 252/349: Converting op name: mul_21 ( type:  Mul )
# 253/349: Converting op name: 25-leaky ( type:  Maximum )
# 254/349: Converting op name: Pad_11 ( type:  Pad )
# 255/349: Converting op name: 26-convolutional ( type:  Conv2D )
# 256/349: Converting op name: sub_11 ( type:  Sub )
# 257/349: Converting op name: truediv_11 ( type:  RealDiv )
# 258/349: Converting op name: mul_22 ( type:  Mul )
# 259/349: Converting op name: BiasAdd_11 ( type:  BiasAdd )
# 260/349: Converting op name: mul_23 ( type:  Mul )
# 261/349: Converting op name: 27-leaky ( type:  Maximum )
# 262/349: Converting op name: Pad_12 ( type:  Pad )
# 263/349: Converting op name: 28-convolutional ( type:  Conv2D )
# 264/349: Converting op name: sub_12 ( type:  Sub )
# 265/349: Converting op name: truediv_12 ( type:  RealDiv )
# 266/349: Converting op name: mul_24 ( type:  Mul )
# 267/349: Converting op name: BiasAdd_12 ( type:  BiasAdd )
# 268/349: Converting op name: mul_25 ( type:  Mul )
# 269/349: Converting op name: 29-leaky ( type:  Maximum )
# 270/349: Converting op name: concat ( type:  Identity )
# 271/349: Converting op name: Pad_20 ( type:  Pad )
# 272/349: Converting op name: 46-convolutional ( type:  Conv2D )
# 273/349: Converting op name: sub_20 ( type:  Sub )
# 274/349: Converting op name: truediv_20 ( type:  RealDiv )
# 275/349: Converting op name: mul_40 ( type:  Mul )
# 276/349: Converting op name: BiasAdd_20 ( type:  BiasAdd )
# 277/349: Converting op name: mul_41 ( type:  Mul )
# 278/349: Converting op name: 47-leaky ( type:  Maximum )
# 279/349: Converting op name: ExtractImagePatches ( type:  ExtractImagePatches )
# 280/349: Converting op name: 30-maxpool ( type:  MaxPool )
# 281/349: Converting op name: Pad_13 ( type:  Pad )
# 282/349: Converting op name: 31-convolutional ( type:  Conv2D )
# 283/349: Converting op name: sub_13 ( type:  Sub )
# 284/349: Converting op name: truediv_13 ( type:  RealDiv )
# 285/349: Converting op name: mul_26 ( type:  Mul )
# 286/349: Converting op name: BiasAdd_13 ( type:  BiasAdd )
# 287/349: Converting op name: mul_27 ( type:  Mul )
# 288/349: Converting op name: 32-leaky ( type:  Maximum )
# 289/349: Converting op name: Pad_14 ( type:  Pad )
# 290/349: Converting op name: 33-convolutional ( type:  Conv2D )
# 291/349: Converting op name: sub_14 ( type:  Sub )
# 292/349: Converting op name: truediv_14 ( type:  RealDiv )
# 293/349: Converting op name: mul_28 ( type:  Mul )
# 294/349: Converting op name: BiasAdd_14 ( type:  BiasAdd )
# 295/349: Converting op name: mul_29 ( type:  Mul )
# 296/349: Converting op name: 34-leaky ( type:  Maximum )
# 297/349: Converting op name: Pad_15 ( type:  Pad )
# 298/349: Converting op name: 35-convolutional ( type:  Conv2D )
# 299/349: Converting op name: sub_15 ( type:  Sub )
# 300/349: Converting op name: truediv_15 ( type:  RealDiv )
# 301/349: Converting op name: mul_30 ( type:  Mul )
# 302/349: Converting op name: BiasAdd_15 ( type:  BiasAdd )
# 303/349: Converting op name: mul_31 ( type:  Mul )
# 304/349: Converting op name: 36-leaky ( type:  Maximum )
# 305/349: Converting op name: Pad_16 ( type:  Pad )
# 306/349: Converting op name: 37-convolutional ( type:  Conv2D )
# 307/349: Converting op name: sub_16 ( type:  Sub )
# 308/349: Converting op name: truediv_16 ( type:  RealDiv )
# 309/349: Converting op name: mul_32 ( type:  Mul )
# 310/349: Converting op name: BiasAdd_16 ( type:  BiasAdd )
# 311/349: Converting op name: mul_33 ( type:  Mul )
# 312/349: Converting op name: 38-leaky ( type:  Maximum )
# 313/349: Converting op name: Pad_17 ( type:  Pad )
# 314/349: Converting op name: 39-convolutional ( type:  Conv2D )
# 315/349: Converting op name: sub_17 ( type:  Sub )
# 316/349: Converting op name: truediv_17 ( type:  RealDiv )
# 317/349: Converting op name: mul_34 ( type:  Mul )
# 318/349: Converting op name: BiasAdd_17 ( type:  BiasAdd )
# 319/349: Converting op name: mul_35 ( type:  Mul )
# 320/349: Converting op name: 40-leaky ( type:  Maximum )
# 321/349: Converting op name: Pad_18 ( type:  Pad )
# 322/349: Converting op name: 41-convolutional ( type:  Conv2D )
# 323/349: Converting op name: sub_18 ( type:  Sub )
# 324/349: Converting op name: truediv_18 ( type:  RealDiv )
# 325/349: Converting op name: mul_36 ( type:  Mul )
# 326/349: Converting op name: BiasAdd_18 ( type:  BiasAdd )
# 327/349: Converting op name: mul_37 ( type:  Mul )
# 328/349: Converting op name: 42-leaky ( type:  Maximum )
# 329/349: Converting op name: Pad_19 ( type:  Pad )
# 330/349: Converting op name: 43-convolutional ( type:  Conv2D )
# 331/349: Converting op name: sub_19 ( type:  Sub )
# 332/349: Converting op name: truediv_19 ( type:  RealDiv )
# 333/349: Converting op name: mul_38 ( type:  Mul )
# 334/349: Converting op name: BiasAdd_19 ( type:  BiasAdd )
# 335/349: Converting op name: mul_39 ( type:  Mul )
# 336/349: Converting op name: 44-leaky ( type:  Maximum )
# 337/349: Converting op name: concat_1 ( type:  ConcatV2 )
# 338/349: Converting op name: Pad_21 ( type:  Pad )
# 339/349: Converting op name: 50-convolutional ( type:  Conv2D )
# 340/349: Converting op name: sub_21 ( type:  Sub )
# 341/349: Converting op name: truediv_21 ( type:  RealDiv )
# 342/349: Converting op name: mul_42 ( type:  Mul )
# 343/349: Converting op name: BiasAdd_21 ( type:  BiasAdd )
# 344/349: Converting op name: mul_43 ( type:  Mul )
# 345/349: Converting op name: 51-leaky ( type:  Maximum )
# 346/349: Converting op name: Pad_22 ( type:  Pad )
# 347/349: Converting op name: 52-convolutional ( type:  Conv2D )
# 348/349: Converting op name: BiasAdd_22 ( type:  BiasAdd )
# 349/349: Converting op name: output ( type:  Identity )
#
#  Core ML model generated. Saved at location: yolo.mlmodel
#
# Core ML input(s):
#  [name: "input__0"
# type {
#   imageType {
#     width: 608
#     height: 608
#     colorSpace: BGR
#   }
# }
# ]
# Core ML output(s):
#  [name: "output__0"
# type {
#   multiArrayType {
#     shape: 425
#     shape: 19
#     shape: 19
#     dataType: DOUBLE
#   }
# }
# ]
